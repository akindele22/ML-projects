# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
#import xgboost as xgb
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('Book2-Sheet2.csv')

df.head()
# Out:
#                GENDER  MALE   FEMALE MARTIAL STATUS OF HOUSEHOLD  SINGLE  \
# 0        Orita obele     120      80                Orita obele      460
# 1  Akure High school      50     150          Akure High school      650
# 2        Fanibi Lafe      91     109                Fanibi Lafe      486
# 3   Isikan/Ondo road     110      90           Isikan/Ondo road      560
# 4        Ijomu/Ilisa      68     132                Ijomu/Ilisa      668
#
#    MARRIED     NO OF HOUSEHOLD  Unnamed: 7  1-4  5-8  ...  \
# 0      440        Orita obele          NaN  330  570  ...
# 1      460  Akure High school          NaN  920  190  ...
# 2      398        Fanibi Lafe          NaN  556  289  ...
# 3      570   Isikan/Ondo road          NaN  180  860  ...
# 4      512        Ijomu/Ilisa          NaN  315  603  ...
#
#    3HRS:45MINS OR ABOVE   EMPLOYMENT STATUS SELF EMPLOYED  MANAGERIAL  \
# 0                   NaN         Orita obele           120         NaN
# 1                   NaN  Akure High school            170         NaN
# 2                   NaN        Fanibi Lafe            181         NaN
# 3                   NaN   Isikan/Ondo road            150        20.0
# 4                   NaN        Ijomu/Ilisa            181         NaN
#
#    SUPERVISOR  SEMI-SKILLED  UNSKILLED MODE OF TRANSPORTATION  COMMERCIAL  \
# 0        10.0            30       40.0            Orita obele         170
# 1        20.0            10        NaN     Akure High school          160
# 2         NaN            15        4.0           Fanibi Lafe          158
# 3        17.0            13        NaN      Isikan/Ondo road          130
# 4         2.0             5       12.0           Ijomu/Ilisa          150
#
#    PRIVATE
# 0       30
# 1       40
# 2       42
# 3       70
# 4       50
#
# [5 rows x 127 columns]

# %%
df.columns
# Out:
# Index(['GENDER', 'MALE ', 'FEMALE', 'MARTIAL STATUS OF HOUSEHOLD', 'SINGLE',
#        'MARRIED', 'NO OF HOUSEHOLD', 'Unnamed: 7', '1-4', '5-8',
#        ...
#        '3HRS:45MINS OR ABOVE', 'EMPLOYMENT STATUS', 'SELF EMPLOYED',
#        'MANAGERIAL', 'SUPERVISOR', 'SEMI-SKILLED', 'UNSKILLED',
#        'MODE OF TRANSPORTATION', 'COMMERCIAL', 'PRIVATE'],
#       dtype='object', length=127)
